# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
titanic_data = pd.read_csv("train.csv")
# print(titanic_data.head())
print(titanic_data.describe())
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
from sklearn.model_selection import StratifiedShuffleSplit

split = StratifiedShuffleSplit(n_splits=1, test_size=0.2, random_state=42)

# Pass only the 1D target column
for train_indices, test_indices in split.split(titanic_data, titanic_data["Survived"]):
    strat_train_set = titanic_data.loc[train_indices]
    strat_test_set = titanic_data.loc[test_indices]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 6
#       2
#       3 split = StratifiedShuffleSplit(n_splits=1, test_size=0.2, random_state=42)
#       4
#       5 # Pass only the 1D target column
# ----> 6 for train_indices, test_indices in split.split(titanic_data, titanic_data["Survived"]):
#       7     strat_train_set = titanic_data.loc[train_indices]
#       8     strat_test_set = titanic_data.loc[test_indices]
#
# NameError: name 'titanic_data' is not defined
